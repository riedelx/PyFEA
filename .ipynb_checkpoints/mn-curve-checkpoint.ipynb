# %% [markdown]
# # MN-curves

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.insert(1, 'libraries')
import MNcurve as MN
import sections as sect
import materials as mat
import utils

# %% [markdown]
# ## Define geometry

# %% [markdown]
# ## Define materials
#
# Refer to _materials.ipynb_ to learn how the material properties were defined for the D-Frame system.

# %%
conMat = mat.con1('C50_60', 50, 250, epsilon_t2 = 0.001, fc2_factor = 0.1, ft_factor = 0.5, 
                 characteristic = True, plotting=True,title="C50/60")

# %%
conMat.data_frame()
# Out:
#             ID $$h[mm]$$ $$f_{c1}[MPa]$$ $$f_{c2}[MPa]$$ $$f_{t}[MPa]$$  \
# C50_60  C50_60       250              50             5.0            2.2
#
#        $$E_{c0}[MPa]$$ $$E_{c1}[MPa]$$ $$E_{c2}[MPa]$$ $$E_{t1}[MPa]$$  \
# C50_60           38600           22700           -9800           38600
#
#        $$E_{t2}[MPa]$$ $$G_{f}[N/mm]$$ $$G_{c}[N/mm]$$ $$e_{c1}$$ $$e_{c2}$$  \
# C50_60           -2300           0.152            38.0     0.0022     0.0068
#
#        $$e_{t1}$$ $$e_{t2}$$ $$alpha$$
# C50_60      6e-05      0.001       0.7

# %%
# conMat = mat.stl1('concrete stl1', 11111, 15, 15, 0.0035,title="Concrete",plotting=True,tension=False)
# # conMat = mat.EC2con('concrete EC2', 30*0.85/1.5, 0.0035,plotting=True,title="Concrete",tension=False)
# conMat.data_frame()

# %%
reinfMat = mat.stl1('reinforcement', 205000, 560, 670, 0.14,title="Reinforcement",plotting=True,tension=True)
reinfMat.data_frame()
# Out:
#                           ID $$E_{1}[MPa]$$ $$E_{2}[MPa]$$ $$f_{y}[MPa]$$  \
# reinforcement  reinforcement         205000          801.3            560
#
#               $$f_{u}[MPa]$$ $$e_{y}$$ $$e_{u}$$     $$mu$$
# reinforcement            670   0.00273      0.14  0.0039088

# %%
# reinfMat = mat.stl1('reinf plastic', 200000, 435, 435, 0.05,title="Reinforcement",plotting=True,tension=True)
# reinfMat.data_frame()

# %% [markdown]
# ## Define sections

# %%
reinf_sect = [[7, 25, 697],[2, 16, 605],[2,16,387],[2,25,207],[4,25,143],[2,20,103],[2,20,63],[4,25,63]]
section=sect.rcts(190,560,650,340,reinf_sect)

# %%
# reinf_sect = [[2, 20, 40],[2,20,260]]
# section=sect.rss(300,300,reinf_sect, plotting = True)

# %%
# reinf_sect = [[5, 32, 600],[2,25,50]]
# section=sect.rss(500,650,reinf_sect, plotting = True)

# %% [markdown]
# ## Strains and stresses within section
#
# Positive moment indicates tension in top of the section and compression close to 0 x-coordinate.

# %%
MNclass=MN.MNclass(conMat,reinfMat,section)

# %%
# f_tot,m_tot,f_s,f_con,eps_s,sigma_s=MNclass.calc(eps0=0.04,epsH=-0.0035, plotting=True,n_layers=800)
#f_tot,m_tot,f_s,f_con,eps_s,sigma_s=MNclass.calcXH(epsH=-0.0035,x_NA=90, plotting=True,n_layers=800)
#f_tot,m_tot,f_s,f_con,eps_s,sigma_s=MNclass.calcXH(epsH=reinfMat.epsilon_u,x_NA=1E99, plotting=True, n_layers=200)
f_tot,m_tot,f_s,f_con,eps_s,sigma_s=MNclass.calcX0(eps0=-0.0035,x_NA=218.5, plotting=True,n_layers=1000)
# Out:
# Total axial force: -2053 kN
# Total moment: 1964 kNm

# %% [markdown]
# ## MN cuve

# %%
mnInteraction = MNclass.mnCurve(xRatio=[0.16,0.2,0.3,0.4,0.5,0.8,0.9,1,1E99],n_layers=100,epsU=-0.0035,reverseMoment=False)
# Out:
# libraries\utils.py:103: RuntimeWarning: invalid value encountered in greater_equal
#   in_range= (T[0,:] >=0) & (T[1,:] >=0) & (T[0,:] <=1) & (T[1,:] <=1)
# libraries\utils.py:103: RuntimeWarning: invalid value encountered in less_equal
#   in_range= (T[0,:] >=0) & (T[1,:] >=0) & (T[0,:] <=1) & (T[1,:] <=1)

# %%
mnInteraction
# Out:
#         F     M
# 0    6388  -243
# 1     913  1275
# 2    -272  1560
# 3   -2249  2010
# 4   -3737  2277
# 5   -4933  2416
# 6   -9516  1986
# 7  -11006  1737
# 8  -12573  1391
# 9  -16189  -461
# 10 -13500 -1863
# 11 -12238 -2136
# 12 -10895 -2378
# 13  -5684 -3084
# 14  -4171 -3059
# 15  -2833 -2828
# 16   -875 -2367
# 17     45 -2118
# 18   6388  -243

# %%
def mnCurve(self,xRatio=[0.16,0.2,0.3,0.4,0.5,0.8,0.9,1,1E99],n_layers=100,epsU=-0.0035):
    F=[]
    M=[]
    xRatio=[i*self.h for i in xRatio]
    f_tot,m_tot,f_s,f_con,eps_s,sigma_s=self.calcX0(eps0=self.reinf.epsilon_u,x_NA=1E99, plotting=False, n_layers=n_layers)
    F.append(int(f_tot/1E3))
    M.append(int(m_tot/1E6))
    for i in xRatio:
        #print(i)
        f_tot,m_tot,f_s,f_con,eps_s,sigma_s=self.calcX0(eps0=epsU,x_NA=i, plotting=False, n_layers=n_layers)
        F.append(int(f_tot/1E3))
        M.append(int(m_tot/1E6))
    #for i in xRatio[:-1]:
    for i in xRatio[-2::-1]:
        #print(-i)
        f_tot,m_tot,f_s,f_con,eps_s,sigma_s=self.calcXH(epsH=epsU,x_NA=i, plotting=False, n_layers=n_layers)
        F.append(int(f_tot/1E3))
        M.append(int(m_tot/1E6))
    f_tot,m_tot,f_s,f_con,eps_s,sigma_s=self.calcX0(eps0=self.reinf.epsilon_u,x_NA=1E99, plotting=False, n_layers=n_layers)
    F.append(int(f_tot/1E3))
    M.append(int(m_tot/1E6))
    mnInteraction = pd.DataFrame(np.array([F,M]).T,columns=['F','M'])#.sort_values(by=['x'])
    mnInteraction['M']=-mnInteraction['M']
    fig,ax = utils.plotBase()
    ax.plot(mnInteraction['M'],mnInteraction['F'],'-o', linewidth=2, markersize=5)
    ax.set_title('M-N interaction diagram')
    ax.set_xlabel('Moment [kNm]')
    ax.set_ylabel('Axial load [kN]')
    plt.show()
    return mnInteraction
mnInteraction = mnCurve(MNclass,xRatio=[0.16,0.2,0.3,0.4,0.5,0.8,0.9,1,1E99],n_layers=100,epsU=-0.0035)

# %%
mnInteraction['M']=-mnInteraction['M']
mnInteraction
# Out:
#         F     M
# 0    6388   243
# 1     913 -1275
# 2    -272 -1560
# 3   -2249 -2010
# 4   -3737 -2277
# 5   -4933 -2416
# 6   -9516 -1986
# 7  -11006 -1737
# 8  -12573 -1391
# 9  -16189   461
# 10 -13500  1863
# 11 -12238  2136
# 12 -10895  2378
# 13  -5684  3084
# 14  -4171  3059
# 15  -2833  2828
# 16   -875  2367
# 17     45  2118
# 18   6388   243
